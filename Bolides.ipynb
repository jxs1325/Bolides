# %%
# import numpy as np
# from scipy.special import erf

# Mhold=[]
# Shold=[]
# for i in range(0,16):
#     vx=-550.0+i*50.0
#     for j in range(0,16):
#         vz=-550.0+j*50.0
#         for k in range(0,16):
#             vy=-550.0+k*50.0  #this is in the Galactic rest frame
#             #print(np.sqrt(vx**2+vy**2+vz**2))
#             if (np.sqrt(vx**2+vy**2+vz**2)>550.0):
#                 a=1
#                 #do nothing
#             else:
#                 vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)
#                 for j in range(1,5):
#                     for r in range(1,10):
#                         d=r*10**j
#                         sigmax=6*10**-6*((d)*np.exp(3*d/20000))**(1.0/2)*(250/vrel)**2.0
#                         fracx=erf(11/5)-erf(abs(vx)/250.0)
#                         fracz=erf(11/5)-erf(abs(vz)/250.0)
#                         fracy1=0.5*(erf(11/5)-erf(abs(vy)/250.0))
#                         vy2=abs(vy-200)+200
#                         fracy2=0.5*(erf(11/5)-erf(abs(vy2)/250.0))
#                         if fracy1<0.0:
#                             fracy1=0.0
#                         if fracy2<0.0:
#                             fracy2=0.0
#                         fracy=fracy1+fracy2
#                         frac=fracx*fracy*fracz
#                         if frac>1.0:
#                             print('frac greater than 1.0',fracx,fracy,fracz)
#                         Mx=(d/10**5)**2*4*10**8*(frac)*(vrel/250)
                        
#                         Mhold.append(Mx)
#                         Shold.append(sigmax)
                        
# # print(max(Mhold),min(Shold),len(Mhold))
# S=[]
# M=[]
# # Stemp=[]
# for k in range(1,9):
#     for i in range(1,10):
#         Stemp=[]
#         for h in range(len(Mhold)):
#             if i*10**k < Mhold[h] < (i+1)*10**k:
# #                 print(Mhold[h],Shold[h])
# #                 print((i+1)*10**k)
# #                 print(Shold[h])
#                 Stemp.append(Shold[h])
#         if len(Stemp) > 0:
#             S.append(min(Stemp))
#             M.append((2*i+1)*10**k/2)
        
# print(M,S,len(M))

# %%
import numpy as np

Mhold=[]
Shold=[]
vbar=0.0
f=0.0
# print(f)
Vhold=800.0
for i in range(0,22):
    vx=550.0-i*50.0
    for j in range(0,22):
        vz=550.0-j*50.0
        for k in range(0,22):
            vy=550.0-k*50.0  #this is in the Galactic rest frame
            
            if (np.sqrt(vx**2+vy**2+vz**2)>550.0):
                a=1
                #do nothing
            else:
                vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)
                if Vhold<vrel:
                    vrel=Vhold
                else:
                    vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)
                if(vrel>325.0):
                    f=f+np.exp(-(vx**2+vy**2+vz**2)/(250.0**2))*(50.0**3)/(np.pi*250.0**2)**1.5
                    vbar=vbar+(vrel)*np.exp(-(vx**2+vy**2+vz**2)/(250.0**2))*(50.0**3)/(np.pi*250.0**2)**1.5

#                     print(f, vbar, vrel, vx, vz, vy)
                    for j in range(1,5):
                        for r in range(1,10):
                            d=r*10**j
                            sigmax=6*10**-6*((d)*np.exp(3*d/20000))**(1.0/2)*(250/vrel)**2.0
                            Mx=(d/10**5)**2*7700*vbar*1000/3
                            Mhold.append(Mx)
                            Shold.append(sigmax)
                    Vhold=vrel
# # print(Shold,Mhold,len(Mhold))

S=[]
M=[]
# Stemp=[]
for k in range(1,9):
    for i in range(1,10):
        Stemp=[]
        for h in range(len(Mhold)):
            if i*10**k < Mhold[h] < (i+1)*10**k:
#                 print(Mhold[h],Shold[h])
#                 print((i+1)*10**k)
#                 print(Shold[h])
                Stemp.append(Shold[h])
        if len(Stemp) > 0:
            S.append(min(Stemp))
            M.append((2*i+1)*10**k/2)
        
print(M,S,len(M))
# Out:
# [15.0, 25.0, 35.0, 45.0, 55.0, 65.0, 75.0, 85.0, 95.
BH(M):
    f = pi*(3*10**5)**2 *(M/(2.*10**33))**2
    return f

#Atomic Density
def atom(M):
    f = pi*(3/(4*pi*1*10**0))**(2./3) *pow(M,2./3)
    return f

M1=np.logspace(1,10)
MMica = np.logspace(-10, 2.204)# for M_max=160g
MMica1 = np.logspace(-12,1.43,num=1000)#  2.204 for M_max=160g  1.74 for M_max = 55g  1.43 for M_max=27.5g
MMica2 = np.logspace(1.43,1.74,num=1000)
MKepler = np.logspace(24.6,26.3)
MLMC = np.logspace(26.08,34.8)
Mmicro = np.logspace(20,24.6)
Mbolide=np.logspace(0,5.9)

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)

#X-axis
ax.set_xlabel('$M_\t{X}$ [g]',fontsize=18)
#xmin=-2
#xmax=40
ax.set_xlim([M1.min(),M1.max()])

#Y-axis
ymin=10**-9#nuc(M1).min()#10**(-15)
ymax=float(10**9)#nuc(M1).max()#10**15
ax.set_ylim([ymin,ymax])
ax.set_ylabel('$\sigma_\t{X}$ [cm$^{2}$]',fontsize=18)

#Make Plot
ax.loglog(M1, atom(M1), 'k', markersize=4, color='k',lw=1,label='Atomic density',zorder=3)
ax.loglog(M1, nuc(M1), 'k', markersize=4, color='g',lw=2,label='Nuclear density',zorder=3)
ax.loglog(M1, BH(M1), 'k', markersize=4, color='m',lw=3,label='Black holes',zorder=5)

line3 = plt.Polygon(micalines, closed=None, fill=True, facecolor='yellow', edgecolor='black',alpha=0.8, hatch="|",lw=1,zorder=0)# edgecolor='r'
plt.gca().add_line(line3)

linebolide = plt.Polygon(bolidespace, closed=None, fill=True, facecolor='green', edgecolor='black',alpha=2, hatch="//",lw=2,zorder=8)# edgecolor='r'
plt.gca().add_line(linebolide)

lines1 = plt.Polygon(shot, closed = True, fill = True, facecolor = 'red', edgecolor='black',alpha = 1, lw = 0.5,hatch = "",zorder=3)
plt.gca().add_line(lines1)

lineDFN = plt.Polygon(DFN, closed=None, fill=True, facecolor='green', edgecolor='black',alpha=2, hatch="",lw=2,zorder=5)# edgecolor='r'
plt.gca().add_line(lineDFN)

lineDFNfuture = plt.Polygon(DFNfuture, closed=None, fill=True, facecolor='none', edgecolor='green',alpha=2, hatch="+",lw=2,zorder=4)# edgecolor='r'
plt.gca().add_line(lineDFNfuture)

lineh = plt.Polygon(JEM, closed = True, fill = True, facecolor = 'none', edgecolor='purple', alpha = 1, lw = 2,hatch = "//",zorder=0)
plt.gca().add_line(lineh)

plt.fill_between(M1, CMB(M1),ymax,where=None, color='grey',edgecolor='black',hatch="",alpha=.7,zorder=3)#SIDM ,alpha=.5

legBoehm_CMB = Rectangle((0, 0), 1, 1, fc='grey',edgecolor='black', hatch="",alpha=.7)
legMicaEl = Rectangle((0, 0), 1, 1, fc="yellow",edgecolor='black', hatch="|",alpha=1)
legPCE = Rectangle((0, 0), 1, 1, fc='green',edgecolor='black', hatch="//",alpha=1)
legDFN = Rectangle((0, 0), 1, 1, fc="green",edgecolor='black', hatch="",alpha=1)
legDFNfuture= Rectangle((0, 0), 1, 1, fc="white",edgecolor='green', alpha=1,hatch="++")
legWD = Rectangle((0, 0), 1, 1, fc="blue",edgecolor='black', hatch="",alpha=1)
legshot = Rectangle((0, 0), 1, 1, fc="red",edgecolor='black', hatch="",alpha=1)
legJEM = Rectangle((0, 0), 1, 1, fc="white",edgecolor='purple', hatch="//",alpha=1)
plt.rc('legend',**{'fontsize':7.7})

lineWD1 = plt.Polygon(WD1, closed=None, fill=True, facecolor='blue', edgecolor='black',alpha=0.8, hatch="",lw=1,zorder=2)# edgecolor='r'
plt.gca().add_line(lineWD1)

# leg = ax.legend(loc='lower right', shadow=True)
leg2 = legend(([legMicaEl, legBoehm_CMB, legPCE, legDFN, legDFNfuture, legJEM, legWD, legshot]),[ "Mica", "CMB", "PCE", "DFN", "DFN future", "Fluorescence", "White dwarfs", "Human Impacts"],loc='upper left')
#gca().add_artist(leg) #Needto add this back otherwise leg2 removes it  ,legBBNcausalT,legBBNcausalM   ,"Causality (T)","Causality (M)"


# textstr2='CMB'
# props = dict(boxstyle='round', facecolor='none', alpha=0.)

# # place a text box in upper left in axes coords
# ax.text(0
           [2500000.0, 8.477139324212615e-05], [3500000.0, 9.399312193065669e-05], [5500000.0, 0.00014136273162022943], 
           [6500000.0, 0.00018382618182964856], [7500000.0, 0.00020069002704380904], [8500000.0, 0.0002269533403593201], 
           [9500000.0, 0.0002599267498828469], [15000000.0, 0.0003621625627562366], [25000000.0, 0.00044086328541062194], 
           [35000000.0, 0.0005612104840646488], [45000000.0, 0.00083281395053211199], [55000000.0, 0.00104677507166784], 
           [65000000.0, 0.0014253118559161714], [85000000.0, 0.0020921081883149065], [95000000.0, 0.00227058535799503], 
           [150000000.0, 0.00362696596228035943], [250000000.0, 0.005653563324719888], [350000000.0, 0.013507150913539285], 
           [450000000.0, 0.0306308424108944], [550000000.0, 0.06783231889840768], [650000000.0, 0.09027522360023248], 
           [750000000.0, 0.187997153732037686],
           [850000000.0,8617.7],[8500000.0,416.5],[0.0025,3*10**-6],[15.1,3.2*10**-6]]

for i in range(len(DFNfuture)):
    DFNfuture[i][0]=DFNfuture[i][0]/2
#     print(DFN[i][0])
print(DFNfuture)

# %%
import numpy as np
from scipy.special import erf

Mhold=[]
Shold=[]
Vhold=[]
Dhold=[]
for i in range(0,16):
    vx=-550.0+i*50.0
    for j in range(0,16):
        vz=-550.0+j*50.0
        for k in range(0,16):
            vy=-550.0+k*50.0  #this is in the Galactic rest frame
            #print(np.sqrt(vx**2+vy**2+vz**2))
            if (np.sqrt(vx**2+vy**2+vz**2)>550.0):
                a=1
                #do nothing
            else:
                vrel=np.sqrt(42.1**2+vx**2+vz**2+(vy-200.0)**2)
                for j in range(1,5):
                    for r in range(1,11):
                        d=r*10**j*1.0
                        sigmax=2.0*10**-6*((d)*np.exp(3*d/20000))**(1.0/2)*(250/vrel)**2.0
                        fracx=erf(320.0/250.0)-erf(abs(vx)/250.0)  #conservative: putting in 320 instead of 550 for upper bound of integral
                        fracz=erf(320.0/250.0)-erf(abs(vz)/250.0)
                        fracy1=0.5*(erf(320.0/250.0)-erf(abs(vy)/250.0))
                        vy2=abs(vy-200.0)+200.0
                        fracy2=0.5*(erf(320.0/250.0)-erf(abs(vy2)/250.0))
                        if fracy1<0.0:
                            fracy1=0.0
                        if fracy2<0.0:
                            fracy2=0.0
                        if fracx<0.0:
                            fracx=0.0
                        if fracz<0.0:
                            fracz=0.0
                        fracy=fracy1+fracy2
                        frac=fracx*fracy*fracz
                        if frac>1.0:
                            print('frac greater than 1.0',fracx,fracy,fracz)
                        Mx=(d/10**5)**2*8*10**8*(frac)
                        
                        Mhold.append(Mx)
                        Shold.append(sigmax)
                        Vhold.append(vrel)
#                         Dhold.append(d)
                        
# print(max(Mhold),min(Shold),len(Mhold))
S=[]
M=[]
V=[]
# D=[]
for k in range(1,9):
    for i in range(1,10):
        Stemp=[]
        Vtemp=[]
#         Dtemp=[]
        for h in range(len(Mhold)):
            if i*10**k < Mhold[h] < (i+1)*10**k:
#                 print(Mhold[h],Shold[h])
#                 print((i+1)*10**k)
#                 print(Shold[h])
                Stemp.append(Shold[h])
                Vtemp.append(Vhold[h])
#                 Dtemp.append(Dhold[h])
        if len(Stemp) > 0:
            S.append(min(Stemp))
            q = Stemp.index(min(Stemp))
            V.append(Vtemp[q])
#             D.append(Dtemp[q])
            M.append((2*i+1)*10**k/2)
        
print(M,S,V)

# %%
Mx=100
D=6*10**4
v=V[i]
for j in range(0,5):
    sigma = 10**-3*10**j
    F = 3000*(1/D)*np.exp(-3*D/10000)*sigma*v**4*np.exp(-(4000*np.exp(-D/10000)*sigma/Mx))
    print(F,sigma/Mx)
